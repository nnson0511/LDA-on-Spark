# %% [markdown]
# <a href="https://colab.research.google.com/github/nnson0511/LDA-on-Spark/blob/main/LDA_on_spark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
import urllib.request
from textblob import TextBlob
import seaborn as sns
import time

import re
import nltk
import spacy
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
nltk.download('punkt')
nltk.download('stopwords')

import gensim
from gensim import corpora, models
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# w:\Học thạc sĩ\Khai phá dữ liệu song song và phân tán\Code\LDA-on-Spark\LDA_on_spark copy.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/w%3A/H%E1%BB%8Dc%20th%E1%BA%A1c%20s%C4%A9/Khai%20ph%C3%A1%20d%E1%BB%AF%20li%E1%BB%87u%20song%20song%20v%C3%A0%20ph%C3%A2n%20t%C3%A1n/Code/LDA-on-Spark/LDA_on_spark%20copy.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> import nltk
#      <a href='vscode-notebook-cell:/w%3A/H%E1%BB%8Dc%20th%E1%BA%A1c%20s%C4%A9/Khai%20ph%C3%A1%20d%E1%BB%AF%20li%E1%BB%87u%20song%20song%20v%C3%A0%20ph%C3%A2n%20t%C3%A1n/Code/LDA-on-Spark/LDA_on_spark%20copy.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> import spacy
# ---> <a href='vscode-notebook-cell:/w%3A/H%E1%BB%8Dc%20th%E1%BA%A1c%20s%C4%A9/Khai%20ph%C3%A1%20d%E1%BB%AF%20li%E1%BB%87u%20song%20song%20v%C3%A0%20ph%C3%A2n%20t%C3%A1n/Code/LDA-on-Spark/LDA_on_spark%20copy.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> spacy.download('en_core_web_lg')
#      <a href='vscode-notebook-cell:/w%3A/H%E1%BB%8Dc%20th%E1%BA%A1c%20s%C4%A9/Khai%20ph%C3%A1%20d%E1%BB%AF%20li%E1%BB%87u%20song%20song%20v%C3%A0%20ph%C3%A2n%20t%C3%A1n/Code/LDA-on-Spark/LDA_on_spark%20copy.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> from nltk.tokenize import RegexpTokenizer
#      <a href='vscode-notebook-cell:/w%3A/H%E1%BB%8Dc%20th%E1%BA%A1c%20s%C4%A9/Khai%20ph%C3%A1%20d%E1%BB%AF%20li%E1%BB%87u%20song%20song%20v%C3%A0%20ph%C3%A2n%20t%C3%A1n/Code/LDA-on-Spark/LDA_on_spark%20copy.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a> from nltk.tokenize import word_tokenize
#
# AttributeError: module 'spacy' has no attribute 'download'

# %% [markdown]
# # Tiền xử lý dữ liệu

# %%
df = pd.read_csv('sotu_texts.csv')
df
# Out:
#              President  Year  \
# 0    George Washington  1790
# 1    George Washington  1790
# 2    George Washington  1791
# 3    George Washington  1792
# 4    George Washington  1793
# ..                 ...   ...
# 215       Barack Obama  2016
# 216       Donald Trump  2017
# 217       Donald Trump  2018
# 218       Donald Trump  2019
# 219          Joe Biden  2022
#
#                                                 Title  \
# 0                    First State of the Union Address
# 1                   Second State of the Union Address
# 2                    Third State of the Union Address
# 3                   Fourth State of the Union Address
# 4                    Fifth State of the Union Address
# ..                                                ...
# 215  Barack Obama's Eighth State of the Union Address
# 216   Donald Trump's First State of the Union Address
# 217  Donald Trump's Second State of the Union Address
# 218   Donald Trump's Third State of the Union Address
# 219      Joe Biden's First State of The Union Address
#
#                                                   Text
# 0    ['I embrace with great satisfaction the opport...
# 1    ['Fellow-Citizens of the Senate and the House ...
# 2    ['Fellow-Citizens of the Senate and the House ...
# 3    ['Fellow-Citizens of the Senate and of the Hou...
# 4    ['Fellow Citizens of the Senate and of the Hou...
# ..                                                 ...
# 215  ['Mr. Speaker, Mr. Vice President, Members of ...
# 216  ['Mr. Speaker, Mr. Vice President, Members of ...
# 217  ['Mr. Speaker, Mr. Vice President, Members of ...
# 218  ['Madam Speaker, Mr. Vice President, Members o...
# 219  ['Madam Speaker, Madam Vice President, our Fir...
#
# [220 rows x 4 columns]

# %%
# Tính số lượng từ trong mỗi hàng
df['word_count'] = df['Text'].apply(lambda x: len(str(x).split()))

# Tìm số lượng từ tối thiểu và tối đa
min_word_count = df['word_count'].min()
max_word_count = df['word_count'].max()

print(f"Minimum word count: {min_word_count}")
print(f"Maximum word count: {max_word_count}")
# Out:
# Minimum word count: 1067
# Maximum word count: 33577

# %%
# Preprocess pipeline with nltk:
def nltk_preprocess(text):
    # Chuyển đổi văn bản thành chữ thường
    text = text.lower()
    # Loại bỏ dấu câu và ký tự đặc biệt
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # Tokenize văn bản
    tokens = word_tokenize(text)
    # Loại bỏ stopwords và dấu câu
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.isalnum() and word not in stop_words]
    # Lemmatization (Steming)
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(word) for word in tokens]
    return tokens
    
nlp = spacy.load('en_core_web_lg', disable=['parser', 'ner']) # disabling the parser makes it run faster
# Preprocess pipeline with spacy: 
def spacy_preprocess(text): 
    text_out = []
    for token in nlp(text.lower()):
        # Loại bỏ stopwords và ký tự không phải chữ và số
        if not token.is_stop and token.is_alpha and len(token)>1:
            lemma = token.lemma_
            if lemma != '-PRON-':
                text_out.append(lemma)
            else:
                text_out.append(token.text)            
    return(text_out)

# %%
df['nltk-tokens'] = df['Text'].apply(nltk_preprocess)
df['spacy-tokens'] = df['Text'].apply(spacy_preprocess)

df
# Out:
#              President  Year  \
# 0    George Washington  1790
# 1    George Washington  1790
# 2    George Washington  1791
# 3    George Washington  1792
# 4    George Washington  1793
# ..                 ...   ...
# 215       Barack Obama  2016
# 216       Donald Trump  2017
# 217       Donald Trump  2018
# 218       Donald Trump  2019
# 219          Joe Biden  2022
#
#                                                 Title  \
# 0                    First State of the Union Address
# 1                   Second State of the Union Address
# 2                    Third State of the Union Address
# 3                   Fourth State of the Union Address
# 4                    Fifth State of the Union Address
# ..                                                ...
# 215  Barack Obama's Eighth State of the Union Address
# 216   Donald Trump's First State of the Union Address
# 217  Donald Trump's Second State of the Union Address
# 218   Donald Trump's Third State of the Union Address
# 219      Joe Biden's First State of The Union Address
#
#                                                   Text  word_count  \
# 0    ['I embrace with great satisfaction the opport...        1067
# 1    ['Fellow-Citizens of the Senate and the House ...        1404
# 2    ['Fellow-Citizens of the Senate and the House ...        2260
# 3    ['Fellow-Citizens of the Senate and of the Hou...        2100
# 4    ['Fellow Citizens of the Senate and of the Hou...        1968
# ..                                                 ...         ...
# 215  ['Mr. Speaker, Mr. Vice President, Members of ...        5465
# 216  ['Mr. Speaker, Mr. Vice President, Members of ...        5022
# 217  ['Mr. Speaker, Mr. Vice President, Members of ...        5185
# 218  ['Madam Speaker, Mr. Vice President, Members o...        5147
# 219  ['Madam Speaker, Madam Vice President, our Fir...        6471
#
#                                            nltk-tokens  \
# 0    [embrac, great, satisfact, opportun, present, ...
# 1    [fellowcitizen, senat, hous, repres, meet, fee...
# 2    [fellowcitizen, senat, hous, repres, meet, upo...
# 3    [fellowcitizen, senat, hous, repres, abat, sat...
# 4    [fellow, citizen, senat, hous, repres, sinc, c...
# ..                                                 ...
# 215  [mr, speaker, mr, vice, presid, member, congre...
# 216  [mr, speaker, mr, vice, presid, member, congre...
# 217  [mr, speaker, mr, vice, presid, member, congre...
# 218  [madam, speaker, mr, vice, presid, member, con...
# 219  [madam, speaker, madam, vice, presid, first, l...
#
#                                           spacy-tokens
# 0    [embrace, great, satisfaction, opportunity, pr...
# 1    [fellow, citizen, senate, house, representativ...
# 2    [fellow, citizen, senate, house, representativ...
# 3    [fellow, citizen, senate, house, representativ...
# 4    [fellow, citizen, senate, house, representativ...
# ..                                                 ...
# 215  [mr, speaker, mr, vice, president, member, con...
# 216  [mr, speaker, mr, vice, president, member, con...
# 217  [mr, speaker, mr, vice, president, member, con...
# 218  [madam, speaker, mr, vice, president, member, ...
# 219  [madam, speaker, madam, vice, president, lady,...
#
# [220 rows x 7 columns]

# %%
headlines_per_president = df.groupby('year')['headline_text'].count()

fig, ax = plt.subplots()
headlines_per_year.plot(kind='bar', ax=ax)
ax.set_title('Số lượng tiêu đề mỗi năm')
ax.set_xlabel('Năm')
ax.set_ylabel('Số lượng tiêu đề')
ax.set_xticklabels(headlines_per_year.index, rotation=0)

if len(headlines_per_year) > 10:
    ax.set_xticks(ax.get_xticks()[::3])
for spine in ax.spines.values():
    spine.set_visible(False)
plt.show()

# %% [markdown]
# # Triển khai Mô hình LDA tuần tự

# %%
# Tạo từ điển dựa trên cột 'tokens'
dictionary = corpora.Dictionary(df['tokens'])

# Tạo document-term matrix (corpus) dựa trên cột 'tokens'
corpus = [dictionary.doc2bow(text) for text in df['tokens']]

# Xác định số lượng chủ đề
num_topics = 20

# Xây dựng mô hình LDA
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, random_state=42)

# %%
# Lấy phân phối chủ đề cho một văn bản cụ thể
document = df.loc[0, 'headline_text'].split()
doc_bow = dictionary.doc2bow(document)
topic_distribution = lda_model.get_document_topics(doc_bow)

# %%
# In ra các chủ đề và các từ quan trọng nhất trong mỗi chủ đề
for topic_num, topic_words in lda_model.show_topics(num_topics=num_topics, num_words=10, formatted=False):
    print(f"Topic {topic_num + 1}:")
    for word, prob in topic_words:
        prob_percentage = prob * 100
        print(f"{word}: {prob_percentage:.2f}%")
    print()
# Out:
# Topic 1:
# govern: 8.17%
# china: 6.74%
# border: 5.72%
# death: 5.48%
# die: 4.84%
# attack: 3.73%
# speak: 3.12%
# rise: 2.73%
# fear: 2.24%
# reveal: 2.14%
#
# Topic 2:
# nsw: 11.48%
# 19: 11.44%
# queensland: 8.30%
# vaccin: 6.99%
# day: 4.36%
# bushfir: 3.89%
# announc: 2.56%
# make: 2.41%
# presid: 1.91%
# child: 1.74%
#
# Topic 3:
# polic: 12.89%
# crash: 4.25%
# investig: 3.47%
# accus: 2.89%
# royal: 2.67%
# continu: 2.57%
# law: 2.46%
# risk: 2.30%
# commiss: 2.22%
# black: 2.16%
#
# Topic 4:
# year: 6.34%
# man: 6.32%
# record: 5.57%
# court: 4.35%
# charg: 4.21%
# first: 3.71%
# murder: 3.52%
# one: 3.49%
# face: 3.36%
# woman: 3.07%
#
# Topic 5:
# case: 12.52%
# health: 6.16%
# news: 5.53%
# live: 5.42%
# warn: 4.31%
# report: 4.19%
# market: 3.46%
# leader: 2.10%
# shoot: 1.96%
# program: 1.95%
#
# Topic 6:
# melbourn: 9.01%
# minist: 5.80%
# tasmania: 5.28%
# show: 4.65%
# island: 4.33%
# uk: 4.03%
# fall: 2.84%
# track: 2.55%
# financ: 2.54%
# near: 2.45%
#
# Topic 7:
# victoria: 9.50%
# nt: 5.00%
# famili: 4.17%
# get: 3.75%
# school: 3.70%
# age: 3.39%
# care: 3.10%
# work: 2.64%
# farmer: 2.55%
# million: 2.45%
#
# Topic 8:
# sa: 6.53%
# brisban: 5.12%
# afl: 3.94%
# find: 3.76%
# hotel: 3.67%
# set: 2.93%
# releas: 2.84%
# india: 2.83%
# old: 2.75%
# victim: 2.58%
#
# Topic 9:
# chang: 7.34%
# qld: 5.22%
# adelaid: 4.58%
# hospit: 4.54%
# indigen: 4.19%
# high: 3.33%
# flood: 3.22%
# support: 3.19%
# power: 2.91%
# assault: 2.67%
#
# Topic 10:
# found: 4.05%
# busi: 4.02%
# premier: 3.84%
# time: 3.61%
# use: 3.14%
# life: 2.83%
# industri: 2.60%
# number: 2.48%
# beach: 2.47%
# farm: 2.32%
#
# Topic 11:
# two: 6.47%
# kill: 5.91%
# close: 4.26%
# final: 4.03%
# end: 3.67%
# need: 3.03%
# darwin: 2.94%
# council: 2.79%
# season: 2.57%
# chines: 2.42%
#
# Topic 12:
# australia: 18.44%
# south: 5.15%
# peopl: 4.12%
# world: 3.86%
# travel: 3.33%
# win: 3.21%
# say: 2.58%
# west: 2.37%
# leav: 2.32%
# price: 2.01%
#
# Topic 13:
# hous: 5.72%
# scott: 4.70%
# victorian: 4.64%
# could: 4.35%
# commun: 4.00%
# local: 3.47%
# three: 2.95%
# updat: 2.93%
# children: 2.70%
# former: 2.39%
#
# Topic 14:
# wa: 10.70%
# women: 5.19%
# hit: 5.05%
# take: 4.77%
# region: 4.21%
# ban: 4.03%
# north: 3.75%
# video: 2.40%
# talk: 2.31%
# appeal: 1.84%
#
# Topic 15:
# us: 12.16%
# restrict: 7.48%
# perth: 4.13%
# water: 3.49%
# pm: 3.17%
# labor: 3.05%
# may: 2.78%
# claim: 2.69%
# countri: 2.41%
# game: 2.24%
#
# Topic 16:
# new: 13.84%
# australian: 12.83%
# home: 5.90%
# canberra: 3.70%
# arrest: 3.20%
# offic: 2.81%
# christma: 2.49%
# servic: 2.02%
# public: 1.90%
# zealand: 1.90%
#
# Topic 17:
# test: 9.30%
# fire: 8.59%
# help: 5.77%
# alleg: 5.06%
# act: 3.35%
# deal: 2.68%
# hear: 2.61%
# trade: 2.29%
# futur: 2.13%
# player: 2.10%
#
# Topic 18:
# call: 9.60%
# protest: 6.60%
# return: 4.72%
# concern: 4.58%
# war: 3.02%
# latest: 2.44%
# media: 2.41%
# parti: 2.39%
# turn: 2.18%
# white: 2.04%
#
# Topic 19:
# nation: 6.14%
# open: 5.97%
# state: 5.76%
# coast: 5.44%
# back: 5.10%
# gold: 3.42%
# fight: 3.05%
# look: 2.81%
# trial: 2.67%
# cut: 2.43%
#
# Topic 20:
# sydney: 10.07%
# elect: 6.93%
# feder: 3.90%
# rule: 3.11%
# nrl: 2.30%
# job: 2.28%
# go: 2.26%
# flight: 2.18%
# parliament: 1.94%
# citi: 1.87%

# %% [markdown]
# # Triển khai Mô hình LDA song song dùng pyspark

# %%
pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=4725f3d5c24523f6df7c2307f9c302b164b3ce68b879564f46ac3f6f881c19f8
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import CountVectorizer
from pyspark.ml.clustering import LDA

# %%
# Ví dụ cho việc tạo 1 session có kết nối đến master và setting cho các executor
# spark = SparkSession \
#     .builder \
#     .appName("abcNews LDA Analysis") \
#     .master("spark://MASTER_NODE_IP:PORT") \
#     .config("spark.executor.memory", "4g") \
#     .config("spark.executor.cores", "2") \
#     .config("spark.shuffle.service.enabled", "true") \
#     .config("spark.dynamicAllocation.enabled", "true") \
#     .config("spark.dynamicAllocation.initialExecutors", "2") \
#     .config("spark.dynamicAllocation.minExecutors", "1") \
#     .config("spark.dynamicAllocation.maxExecutors", "10") \
#     .getOrCreate()

# %%
spark = SparkSession.builder.appName('abcNews').getOrCreate()
tokens_df = spark.createDataFrame(df)
tokens_df.show(5)
# Out:
# +------------+--------------------+
# |publish_date|       headline_text|
# +------------+--------------------+
# |    20030219|aba decides again...|
# |    20030219|act fire witnesse...|
# |    20030219|a g calls for inf...|
# |    20030219|air nz staff in a...|
# |    20030219|air nz strike to ...|
# +------------+--------------------+
# only showing top 5 rows

# %%
# Khởi tạo một đối tượng CountVectorizer với cột đầu vào là 'tokens', cột đầu ra là 'features'.
# vocabSize là số lượng từ tối đa trong từ điển. minDF là tần suất tối thiểu của một từ để được đưa vào từ điển.
cv = CountVectorizer(inputCol="tokens", outputCol="features", vocabSize=500, minDF=3.0)

# Áp dụng CountVectorizer để 'fit' dữ liệu từ DataFrame 'tokens_df', tức là học từ điển từ dữ liệu.
cv_model = cv.fit(tokens_df)

# Transform DataFrame 'tokens_df' sử dụng mô hình CountVectorizer để chuyển đổi cột 'tokens' thành cột 'features'.
# Cột 'features' sẽ chứa vector đếm số lần xuất hiện của mỗi từ trong mỗi tài liệu.
vectorized_tokens = cv_model.transform(tokens_df)

# Hiển thị 5 hàng đầu tiên của DataFrame sau khi đã áp dụng vector hóa.
vectorized_tokens.show(5)
# Out:
# +-------------------+--------------------+----+--------------------+--------------------+
# |       publish_date|       headline_text|year|              tokens|            features|
# +-------------------+--------------------+----+--------------------+--------------------+
# |2003-02-19 00:00:00|aba decides again...|2003|[aba, decid, comm...|   (500,[137],[1.0])|
# |2003-02-19 00:00:00|act fire witnesse...|2003|[act, fire, wit, ...|(500,[10,138],[1....|
# |2003-02-19 00:00:00|a g calls for inf...|2003|[g, call, infrast...|(500,[6,369],[1.0...|
# |2003-02-19 00:00:00|air nz staff in a...|2003|[air, nz, staff, ...|(500,[63,157,207,...|
# |2003-02-19 00:00:00|air nz strike to ...|2003|[air, nz, strike,...|(500,[18,207,237,...|
# +-------------------+--------------------+----+--------------------+--------------------+
# only showing top 5 rows

# %%
# Đặt số lượng chủ đề cần tìm
num_topics = 20

# Khởi tạo mô hình LDA với số lượng chủ đề (k) và số lần lặp tối đa (maxIter)
lda = LDA(k=num_topics, maxIter=50)

# Áp dụng mô hình LDA lên DataFrame đã được vector hóa để tìm các chủ đề
model = lda.fit(vectorized_tokens)

# Xuất mô hình sau khi đã được fit
model
# Out:
# LocalLDAModel: uid=LDA_431905f48946, k=20, numFeatures=500

# %%
# Lấy vocabulary từ CountVectorizer model
vocab = cv_model.vocabulary

# Mô tả các chủ đề được tìm thấy bởi LDA model
topics = model.describeTopics()

# Chuyển đổi DataFrame của Spark thành RDD (Resilient Distributed Dataset)
# và áp dụng một hàm để lấy ra chỉ số của các thuật ngữ (term indices) cho mỗi chủ đề
# sau đó thu thập kết quả về máy local
collected_topics = topics.rdd\
    .map(lambda row: row['termIndices'])\
    .collect()

# Trích xuất và chuyển đổi các chỉ số thuật ngữ thành từ tương ứng từ vocabulary
topics_words = topics.rdd\
    .map(lambda row: row['termIndices'])\
    .map(lambda idx_list: [vocab[idx] for idx in idx_list])\
    .collect()

# %%
vocab
# Out:
# ['polic',
#  'new',
#  'man',
#  'say',
#  'plan',
#  'charg',
#  'call',
#  'us',
#  'australia',
#  'council',
#  'fire',
#  'court',
#  'govt',
#  'win',
#  'back',
#  'nsw',
#  'kill',
#  'interview',
#  'australian',
#  'death',
#  'report',
#  'face',
#  'crash',
#  'warn',
#  'fund',
#  'urg',
#  'sydney',
#  'water',
#  'get',
#  'year',
#  'wa',
#  'attack',
#  'qld',
#  'murder',
#  'chang',
#  'take',
#  'open',
#  'health',
#  'day',
#  'hous',
#  'hit',
#  'mine',
#  'elect',
#  'jail',
#  'home',
#  'market',
#  'miss',
#  'govern',
#  'claim',
#  'hospit',
#  'world',
#  'nation',
#  'car',
#  'sa',
#  'help',
#  'school',
#  'accus',
#  'woman',
#  'die',
#  'cut',
#  'test',
#  'set',
#  'coast',
#  'rise',
#  'south',
#  'two',
#  'may',
#  'drug',
#  'case',
#  'ban',
#  'china',
#  'farmer',
#  'minist',
#  'found',
#  'first',
#  'fear',
#  'job',
#  'coronaviru',
#  'boost',
#  'talk',
#  'flood',
#  'servic',
#  'protest',
#  'final',
#  'investig',
#  'group',
#  'mp',
#  'worker',
#  'melbourn',
#  'road',
#  'make',
#  'continu',
#  'north',
#  'record',
#  'work',
#  'arrest',
#  'price',
#  'concern',
#  'queensland',
#  'power',
#  'fight',
#  'busi',
#  'one',
#  'nt',
#  'cup',
#  'rural',
#  'trial',
#  'return',
#  'labor',
#  'hope',
#  'green',
#  'industri',
#  'lead',
#  'famili',
#  'rate',
#  'law',
#  'child',
#  'deal',
#  'find',
#  'pm',
#  'support',
#  'show',
#  'end',
#  'want',
#  'driver',
#  'seek',
#  'indigen',
#  'push',
#  'sex',
#  'time',
#  'high',
#  'meet',
#  'centr',
#  'abc',
#  'gold',
#  'top',
#  'could',
#  'commun',
#  'act',
#  'state',
#  'dead',
#  'adelaid',
#  'probe',
#  'public',
#  'move',
#  'forc',
#  'former',
#  'news',
#  'union',
#  'victim',
#  'assault',
#  'close',
#  'search',
#  'budget',
#  'train',
#  'feder',
#  'resid',
#  'pay',
#  'west',
#  'canberra',
#  'park',
#  'defend',
#  'region',
#  'brisban',
#  'secur',
#  'live',
#  'countri',
#  'consid',
#  'farm',
#  'still',
#  'fall',
#  'alleg',
#  'rule',
#  'need',
#  'perth',
#  'share',
#  'iraq',
#  'leader',
#  'big',
#  'trump',
#  'bushfir',
#  'inquiri',
#  'reject',
#  'releas',
#  'run',
#  'offic',
#  'head',
#  'guilti',
#  'review',
#  'deni',
#  'go',
#  'offer',
#  'student',
#  'aussi',
#  'use',
#  'women',
#  'opposit',
#  'appeal',
#  'look',
#  'three',
#  'land',
#  'leav',
#  'mayor',
#  'teen',
#  'tax',
#  'storm',
#  'hear',
#  'strike',
#  'local',
#  'question',
#  'delay',
#  'port',
#  'victoria',
#  'shoot',
#  'abus',
#  'lose',
#  'trade',
#  'rain',
#  'island',
#  'bank',
#  'vote',
#  'announc',
#  'name',
#  'put',
#  'welcom',
#  'sentenc',
#  'futur',
#  'sale',
#  'war',
#  'chief',
#  'fatal',
#  'begin',
#  'doctor',
#  'hold',
#  'action',
#  'bodi',
#  'prison',
#  'air',
#  'target',
#  'cost',
#  'race',
#  'bomb',
#  'play',
#  'drought',
#  'speak',
#  'vic',
#  'studi',
#  'campaign',
#  'second',
#  'research',
#  'injur',
#  'develop',
#  'start',
#  'bid',
#  'tasmania',
#  'rescu',
#  'hour',
#  'safeti',
#  'fine',
#  'ahead',
#  'dog',
#  'keep',
#  'afl',
#  'season',
#  'covid',
#  'threat',
#  'bill',
#  'launch',
#  'expect',
#  'decis',
#  'game',
#  'weather',
#  'break',
#  'station',
#  'sign',
#  'life',
#  'parti',
#  'spark',
#  'river',
#  'four',
#  'give',
#  'children',
#  'ta',
#  'tour',
#  'stab',
#  'peopl',
#  'darwin',
#  'premier',
#  'near',
#  'save',
#  'hill',
#  'aid',
#  'reveal',
#  'beat',
#  'tasmanian',
#  'drive',
#  'award',
#  'blaze',
#  'liber',
#  'india',
#  'compani',
#  'un',
#  'unit',
#  'told',
#  'east',
#  'care',
#  'build',
#  'rail',
#  'png',
#  'fail',
#  'project',
#  'emerg',
#  'join',
#  'presid',
#  'stop',
#  'media',
#  'issu',
#  'citi',
#  'ga',
#  'threaten',
#  'risk',
#  'suspect',
#  'violenc',
#  'challeng',
#  'million',
#  'red',
#  'star',
#  'drop',
#  'club',
#  'plead',
#  'anti',
#  'tourism',
#  'link',
#  'battl',
#  'england',
#  'clear',
#  'climat',
#  'free',
#  'polit',
#  'leagu',
#  'tiger',
#  'team',
#  'fish',
#  'boy',
#  'damag',
#  'remain',
#  'increas',
#  'black',
#  'senat',
#  'men',
#  'pakistan',
#  'blue',
#  'turn',
#  'babi',
#  'caus',
#  'stand',
#  'food',
#  'promis',
#  'week',
#  'demand',
#  'prepar',
#  'clash',
#  'critic',
#  'wont',
#  'plane',
#  'nrl',
#  'extend',
#  'right',
#  'confid',
#  'protect',
#  'crime',
#  'town',
#  'hunt',
#  'debat',
#  'teacher',
#  'murray',
#  'boat',
#  'light',
#  'rais',
#  'hunter',
#  'japan',
#  'scheme',
#  'chines',
#  'coal',
#  'blast',
#  'export',
#  'young',
#  'victorian',
#  'despit',
#  'airport',
#  'program',
#  '19',
#  'age',
#  'track',
#  'cancer',
#  'royal',
#  'titl',
#  'beach',
#  'blame',
#  'site',
#  'plant',
#  'loss',
#  'john',
#  'celebr',
#  'polici',
#  'aust',
#  'crisi',
#  'victori',
#  'shark',
#  'korea',
#  'stay',
#  'number',
#  'girl',
#  'parliament',
#  'cattl',
#  'accid',
#  'rudd',
#  'terror',
#  'cyclon',
#  'nz',
#  'five',
#  'sport',
#  'propos',
#  'discuss',
#  'abbott',
#  'author',
#  'nurs',
#  'olymp',
#  'bail',
#  'manag',
#  'coach',
#  'good',
#  'mark',
#  'approv',
#  'truck',
#  'youth',
#  'see',
#  'aborigin',
#  'injuri',
#  'control',
#  'like',
#  'asylum',
#  'visit',
#  'bu',
#  'street',
#  'hobart',
#  'oil',
#  'pacif',
#  'donald',
#  'confirm',
#  'grower',
#  'miner',
#  'defenc',
#  'legal',
#  'highway',
#  'mental',
#  'art',
#  'commiss',
#  'shot',
#  'expert',
#  'staff',
#  'way',
#  'festiv',
#  'highlight',
#  'shire',
#  'toll',
#  'soldier',
#  'honour',
#  'old',
#  'indonesia',
#  'profit',
#  'bush',
#  'player',
#  'christma',
#  'hand',
#  'central',
#  'restrict',
#  'wind',
#  'ralli',
#  'readi',
#  'long',
#  'post',
#  'grant',
#  'northern',
#  'inquest',
#  'uk',
#  'dollar',
#  'troop',
#  'drink',
#  'rape',
#  'sea',
#  'oper',
#  'order',
#  'thousand',
#  'western',
#  'boss',
#  'impact',
#  'prompt',
#  'amid',
#  'system']

# %%
topics
# Out:
# DataFrame[topic: int, termIndices: array<int>, termWeights: array<double>]

# %%
collected_topics
# Out:
# [[140, 201, 213, 263, 180, 199, 366, 365, 458, 420],
#  [31, 76, 87, 59, 99, 102, 141, 154, 65, 197],
#  [42, 61, 63, 103, 137, 165, 192, 220, 236, 231],
#  [8, 17, 14, 29, 40, 45, 50, 47, 104, 100],
#  [35, 73, 89, 88, 133, 135, 151, 169, 72, 160],
#  [18, 51, 71, 70, 77, 93, 212, 218, 179, 264],
#  [23, 41, 83, 106, 210, 239, 188, 260, 285, 297],
#  [15, 26, 28, 38, 95, 80, 108, 112, 68, 129],
#  [22, 49, 21, 56, 24, 82, 119, 36, 122, 193],
#  [46, 78, 91, 109, 94, 114, 152, 153, 168, 249],
#  [75, 189, 243, 257, 300, 320, 398, 404, 383, 379],
#  [86, 158, 155, 178, 219, 253, 399, 395, 436, 413],
#  [4, 16, 9, 39, 62, 96, 97, 115, 134, 157],
#  [0, 6, 43, 55, 84, 11, 52, 107, 120, 125],
#  [3, 110, 163, 173, 252, 338, 400, 406, 416, 363],
#  [34, 30, 101, 123, 131, 147, 162, 202, 254, 296],
#  [2, 5, 19, 33, 48, 58, 90, 57, 113, 11],
#  [12, 27, 25, 37, 66, 156, 161, 186, 191, 175],
#  [7, 10, 74, 117, 92, 164, 221, 240, 228, 234],
#  [1, 13, 20, 60, 81, 111, 127, 138, 145, 146]]

# %%
topics_words
# Out:
# [['dead',
#   'leav',
#   'shoot',
#   'season',
#   'bushfir',
#   'three',
#   'extend',
#   'nrl',
#   'shot',
#   'five'],
#  ['attack',
#   'job',
#   'worker',
#   'cut',
#   'power',
#   'one',
#   'adelaid',
#   'train',
#   'two',
#   'appeal'],
#  ['elect',
#   'set',
#   'rise',
#   'nt',
#   'commun',
#   'live',
#   'student',
#   'vote',
#   'prison',
#   'begin'],
#  ['australia',
#   'interview',
#   'back',
#   'year',
#   'hit',
#   'market',
#   'world',
#   'govern',
#   'cup',
#   'fight'],
#  ['take',
#   'found',
#   'road',
#   'melbourn',
#   'abc',
#   'top',
#   'close',
#   'still',
#   'minist',
#   'park'],
#  ['australian',
#   'nation',
#   'farmer',
#   'china',
#   'coronaviru',
#   'record',
#   'victoria',
#   'island',
#   'trump',
#   'covid'],
#  ['warn',
#   'mine',
#   'final',
#   'trial',
#   'delay',
#   'cost',
#   'review',
#   'dog',
#   'peopl',
#   'blaze'],
#  ['nsw',
#   'sydney',
#   'get',
#   'day',
#   'arrest',
#   'flood',
#   'labor',
#   'lead',
#   'case',
#   'time'],
#  ['crash',
#   'hospit',
#   'face',
#   'accus',
#   'fund',
#   'protest',
#   'pm',
#   'open',
#   'end',
#   'aussi'],
#  ['miss',
#   'boost',
#   'continu',
#   'hope',
#   'work',
#   'rate',
#   'search',
#   'budget',
#   'farm',
#   'research'],
#  ['fear',
#   'deni',
#   'drought',
#   'safeti',
#   'compani',
#   'risk',
#   'blame',
#   'polici',
#   'coal',
#   'hunter'],
#  ['mp',
#   'west',
#   'feder',
#   'big',
#   'bank',
#   'bid',
#   'site',
#   'royal',
#   'see',
#   'parliament'],
#  ['plan',
#   'kill',
#   'council',
#   'hous',
#   'coast',
#   'price',
#   'concern',
#   'law',
#   'gold',
#   'pay'],
#  ['polic',
#   'call',
#   'jail',
#   'school',
#   'investig',
#   'court',
#   'car',
#   'return',
#   'support',
#   'seek'],
#  ['say',
#   'green',
#   'brisban',
#   'need',
#   'start',
#   'polit',
#   'plant',
#   'crisi',
#   'rudd',
#   'wont'],
#  ['chang',
#   'wa',
#   'busi',
#   'want',
#   'meet',
#   'news',
#   'region',
#   'mayor',
#   'tasmania',
#   'award'],
#  ['man',
#   'charg',
#   'death',
#   'murder',
#   'claim',
#   'die',
#   'make',
#   'woman',
#   'famili',
#   'court'],
#  ['govt',
#   'water',
#   'urg',
#   'health',
#   'may',
#   'resid',
#   'defend',
#   'head',
#   'offer',
#   'share'],
#  ['us',
#   'fire',
#   'first',
#   'deal',
#   'north',
#   'secur',
#   'announc',
#   'race',
#   'war',
#   'action'],
#  ['new',
#   'win',
#   'report',
#   'test',
#   'servic',
#   'industri',
#   'push',
#   'act',
#   'forc',
#   'former']]
